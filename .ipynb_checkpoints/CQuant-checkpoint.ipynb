# %%
# Import libraries
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling
sns.set(color_codes=True)
# %matplotlib inline

import plotly.express as px

# %% [markdown]
# ## Task 1. Import Data

# %%
# read data from csv file
contracts = pd.read_csv('contracts/Contracts.csv')
fuel_gda = pd.read_csv('fuelPrices/GDA_TETSTX.csv')
fuel_henry = pd.read_csv('fuelPrices/Henry Hub.csv')
plantParameters = pd.read_csv('plantParameters/Plant_Parameters.csv')
powerPrices_2016 = pd.read_csv('powerPrices/ERCOT_DA_Prices_2016.csv')
powerPrices_2017 = pd.read_csv('powerPrices/ERCOT_DA_Prices_2017.csv')
powerPrices_2018 = pd.read_csv('powerPrices/ERCOT_DA_Prices_2018.csv')
powerPrices_2019 = pd.read_csv('powerPrices/ERCOT_DA_Prices_2019.csv')

# %%
# fuel prices
fuelPrices = pd.concat([fuel_gda, fuel_henry], ignore_index=True)

# %%
fuelPrices
# Out:
#         Variable        Date  Price
# 0     GDA_TETSTX  2019-05-01  2.490
# 1     GDA_TETSTX  2019-04-30  2.420
# 2     GDA_TETSTX  2019-04-29  2.445
# 3     GDA_TETSTX  2019-04-28  2.445
# 4     GDA_TETSTX  2019-04-27  2.445
# ...          ...         ...    ...
# 3677   Henry Hub  2020-09-26  1.895
# 3678   Henry Hub  2020-09-27  1.895
# 3679   Henry Hub  2020-09-28  1.895
# 3680   Henry Hub  2020-09-29  1.835
# 3681   Henry Hub  2020-09-30  1.690
#
# [3682 rows x 3 columns]

# %%
# power prices
powerPrices = pd.concat([powerPrices_2016, powerPrices_2017, powerPrices_2018, powerPrices_2019], ignore_index=True)

# %%
powerPrices
# Out:
#                        Date SettlementPoint  Price
# 0       2016-01-01 00:00:00       HB_BUSAVG  18.42
# 1       2016-01-01 00:00:00      HB_HOUSTON  18.42
# 2       2016-01-01 00:00:00       HB_HUBAVG  18.42
# 3       2016-01-01 00:00:00        HB_NORTH  18.43
# 4       2016-01-01 00:00:00        HB_SOUTH  18.38
# ...                     ...             ...    ...
# 497315  2019-12-31 23:00:00         LZ_LCRA  14.53
# 497316  2019-12-31 23:00:00        LZ_NORTH  14.48
# 497317  2019-12-31 23:00:00        LZ_RAYBN  14.48
# 497318  2019-12-31 23:00:00        LZ_SOUTH  14.70
# 497319  2019-12-31 23:00:00         LZ_WEST  16.78
#
# [497320 rows x 3 columns]

# %% [markdown]
# ## Task 2: Calculate basic descriptive statistics

# %%
powerPrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497320 entries, 0 to 497319
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date             497320 non-null  object
#  1   SettlementPoint  497320 non-null  object
#  2   Price            497320 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 11.4+ MB

# %%
# convert to datetime
powerPrices['Date'] =  pd.to_datetime(powerPrices['Date'])

# %%
powerPrices.set_index(['Date'], inplace=True)

# %%
# group by SettlementPoint, Year, Month
a = powerPrices.groupby(['SettlementPoint',(powerPrices.index.year),(powerPrices.index.month)])

# %%
powerPrices_stats = a.agg(mean_lmp=pd.NamedAgg(column='Price', aggfunc='mean'),
      min_lmp=pd.NamedAgg(column='Price', aggfunc='min'),
      max_lmp=pd.NamedAgg(column='Price', aggfunc='max'),
      std_lmp=pd.NamedAgg(column='Price', aggfunc='std'))

# %%
powerPrices_stats.index.rename(['SettlementPoint', 'year', 'month'], inplace=True)

# %%
powerPrices_stats
# Out:
#                               mean_lmp  min_lmp  max_lmp     std_lmp
# SettlementPoint year month
# HB_BUSAVG       2016 1       19.209301     5.12    54.69    5.485210
#                      2       15.288247     1.79    50.98    5.777172
#                      3       16.755626     1.22    64.31    7.368497
#                      4       18.289347     1.18    93.09    9.506143
#                      5       18.159583     3.03    73.61    8.017221
# ...                                ...      ...      ...         ...
# LZ_WEST         2019 8      128.876465     9.12  3505.60  402.114146
#                      9       83.471139     6.59  5015.25  380.453919
#                      10      49.383360     0.79   873.07   62.396856
#                      11      49.340847     3.60   286.91   31.876126
#                      12      39.502594     7.32   195.71   27.975862
#
# [681 rows x 4 columns]

# %% [markdown]
# ## Task 3: Calculate volatility

# %%
powerPrices_pivot = powerPrices.pivot(columns='SettlementPoint', values='Price')

# %%
# log returns
Prices_log_returns = np.log(1+powerPrices_pivot.pct_change(1))

# %%
Prices_log_returns
# Out:
# SettlementPoint      HB_BUSAVG  HB_HOUSTON  HB_HUBAVG  HB_NORTH    HB_PAN  \
# Date
# 2016-01-01 00:00:00        NaN         NaN        NaN       NaN       NaN
# 2016-01-01 01:00:00  -0.131517   -0.131517  -0.132136 -0.130822       NaN
# 2016-01-01 02:00:00  -0.034008   -0.034008  -0.034030 -0.033326       NaN
# 2016-01-01 03:00:00   0.000640    0.000640   0.000641  0.000639       NaN
# 2016-01-01 04:00:00   0.020280    0.020280   0.020920  0.020241       NaN
# ...                        ...         ...        ...       ...       ...
# 2019-12-31 19:00:00  -0.113805   -0.115898  -0.113862 -0.113977 -0.115046
# 2019-12-31 20:00:00  -0.074149   -0.072480  -0.074765 -0.074848 -0.094134
# 2019-12-31 21:00:00  -0.095138   -0.104981  -0.095253 -0.094735 -0.080728
# 2019-12-31 22:00:00  -0.037983   -0.036719  -0.037375 -0.036743 -0.053643
# 2019-12-31 23:00:00  -0.052537   -0.053229  -0.052573 -0.051881 -0.052426
#
# SettlementPoint      HB_SOUTH   HB_WEST    LZ_AEN    LZ_CPS  LZ_HOUSTON  \
# Date
# 2016-01-01 00:00:00       NaN       NaN       NaN       NaN         NaN
# 2016-01-01 01:00:00 -0.133065 -0.131365 -0.131365 -0.130671   -0.132136
# 2016-01-01 02:00:00 -0.035424 -0.032687 -0.032687 -0.032646   -0.033389
# 2016-01-01 03:00:00  0.000000  0.000639  0.000639  0.001276    0.000640
# 2016-01-01 04:00:00  0.021027  0.020228  0.020228  0.019565    0.020280
# ...                       ...       ...       ...       ...         ...
# 2019-12-31 19:00:00 -0.109291 -0.116825 -0.109472 -0.099072   -0.116555
# 2019-12-31 20:00:00 -0.069411 -0.082515 -0.072849 -0.061510   -0.073663
# 2019-12-31 21:00:00 -0.092576 -0.087384 -0.099695 -0.095848   -0.104983
# 2019-12-31 22:00:00 -0.043485 -0.033109 -0.040351 -0.043538   -0.040429
# 2019-12-31 23:00:00 -0.053704 -0.050772 -0.053704 -0.058541   -0.055196
#
# SettlementPoint       LZ_LCRA  LZ_NORTH  LZ_RAYBN  LZ_SOUTH   LZ_WEST
# Date
# 2016-01-01 00:00:00       NaN       NaN       NaN       NaN       NaN
# 2016-01-01 01:00:00 -0.131365 -0.130822 -0.130822 -0.135572 -0.131365
# 2016-01-01 02:00:00 -0.032687 -0.033326 -0.033326 -0.042368 -0.032687
# 2016-01-01 03:00:00  0.000639  0.000639  0.000639 -0.001312  0.000639
# 2016-01-01 04:00:00  0.020228  0.020241  0.020241  0.022721  0.020228
# ...                       ...       ...       ...       ...       ...
# 2019-12-31 19:00:00 -0.109163 -0.113158 -0.113633 -0.102782 -0.157093
# 2019-12-31 20:00:00 -0.070695 -0.075748 -0.075748 -0.066818 -0.060382
# 2019-12-31 21:00:00 -0.078530 -0.095770 -0.095770 -0.078873 -0.252222
# 2019-12-31 22:00:00 -0.058822 -0.037351 -0.037351 -0.054979 -0.244101
# 2019-12-31 23:00:00 -0.054900 -0.051155 -0.051155 -0.057498 -0.133159
#
# [35060 rows x 15 columns]

# %%
# log returns
Prices_log_returns_month = Prices_log_returns.groupby([(Prices_log_returns.index.year),(Prices_log_returns.index.month)]).mean()

# %%
Prices_log_returns_month
# Out:
# SettlementPoint  HB_BUSAVG  HB_HOUSTON  HB_HUBAVG  HB_NORTH    HB_PAN  \
# Date Date
# 2016 1           -0.000364   -0.000364  -0.000364 -0.000362       NaN
#      2           -0.000782   -0.000759  -0.000796 -0.000763       NaN
#      3            0.000774    0.000753   0.000787  0.000754       NaN
#      4           -0.000049   -0.000048  -0.000052 -0.000046       NaN
#      5            0.000150    0.000161   0.000158  0.000135       NaN
#      6            0.000483    0.000474   0.000479  0.000492       NaN
#      7           -0.000152   -0.000156  -0.000158 -0.000142       NaN
#      8            0.000093    0.000092   0.000098  0.000087       NaN
#      9           -0.000084   -0.000084  -0.000084 -0.000085       NaN
#      10          -0.000236   -0.000154  -0.000244 -0.000255       NaN
#      11           0.000225    0.000140   0.000234  0.000245       NaN
#      12           0.000318    0.000319   0.000317  0.000320       NaN
# 2017 1           -0.000464   -0.000461  -0.000469 -0.000458       NaN
#      2           -0.000489   -0.000030  -0.000574 -0.000460       NaN
#      3            0.000338    0.000435   0.000425  0.000225       NaN
#      4            0.000506    0.000057   0.000516  0.000564       NaN
#      5           -0.000058   -0.000160  -0.000071 -0.000036       NaN
#      6            0.000054    0.000212   0.000078  0.000012       NaN
#      7           -0.000032   -0.000093  -0.000042 -0.000012       NaN
#      8           -0.000099   -0.000187  -0.000099 -0.000126       NaN
#      9           -0.000088   -0.000036  -0.000092 -0.000059       NaN
#      10          -0.000014    0.000109   0.000013 -0.000068       NaN
#      11          -0.000075   -0.000218  -0.000107 -0.000005       NaN
#      12           0.000192    0.000168   0.000187  0.000209       NaN
# 2018 1           -0.000402    0.000002  -0.000389 -0.000463       NaN
#      2           -0.000134   -0.000550  -0.000173 -0.000034       NaN
#      3            0.000087    0.000229   0.000124  0.000002       NaN
#      4            0.000033   -0.000031  -0.000241  0.000287       NaN
#      5            0.000289    0.000243   0.000541  0.000080       NaN
#      6            0.000244    0.000215   0.000247  0.000259       NaN
#      7           -0.000087   -0.000112  -0.000088 -0.000089       NaN
#      8           -0.000114   -0.000086  -0.000106 -0.000139       NaN
#      9            0.000018    0.000016   0.000019  0.000018       NaN
#      10           0.000190    0.000202   0.000177  0.000215       NaN
#      11          -0.000203   -0.000234  -0.000522  0.000148       NaN
#      12          -0.000003   -0.000045   0.000311 -0.000344       NaN
# 2019 1           -0.000072   -0.000032  -0.000084 -0.000062       NaN
#      2            0.000013   -0.000035   0.000024 -0.000003       NaN
#      3            0.000346    0.000374   0.000347  0.000363       NaN
#      4           -0.000492   -0.000472  -0.000600 -0.000348 -0.012479
#      5            0.000237    0.000225   0.000345  0.000091       NaN
#      6           -0.000283   -0.000310  -0.000277 -0.000271       NaN
#      7           -0.000030   -0.000002  -0.000038 -0.000045 -0.000124
#      8            0.000068    0.000070   0.000068  0.000066       NaN
#      9           -0.000268   -0.000056  -0.000317 -0.000286       NaN
#      10           0.000472    0.000272   0.000512  0.000506       NaN
#      11          -0.000419   -0.000340  -0.000475 -0.000416       NaN
#      12          -0.000087   -0.000171  -0.000028 -0.000105       NaN
#
# SettlementPoint  HB_SOUTH       HB_WEST    LZ_AEN    LZ_CPS  LZ_HOUSTON  \
# Date Date
# 2016 1          -0.000364 -3.630779e-04 -0.000363 -0.000363   -0.000364
#      2          -0.000790  6.772152e-04 -0.000737 -0.000745   -0.000759
#      3           0.000783  8.607201e-04  0.000732  0.000739    0.000753
#      4          -0.000046  2.913791e-03 -0.000050 -0.000053   -0.000048
#      5           0.000175  1.583105e-04  0.000149  0.000206    0.000161
#      6           0.000465  4.864328e-04  0.000563  0.000437    0.000475
#      7               -inf -1.702994e-04 -0.000220 -0.000165   -0.000156
#      8           0.000096  1.163178e-04  0.000087  0.000103    0.000092
#      9          -0.000080 -8.567362e-05 -0.000090 -0.000080   -0.000084
#      10         -0.000135 -4.548089e-04 -0.000105 -0.000110   -0.000152
#      11          0.000125  4.524635e-04  0.000095  0.000117    0.000139
#      12          0.000312  3.179422e-04  0.000315  0.000286    0.000319
# 2017 1          -0.000468 -2.953816e-03 -0.000447 -0.000463   -0.000463
#      2          -0.000317           NaN -0.000350 -0.000371   -0.000027
#      3           0.000316  8.883383e-04  0.000245  0.000381    0.000467
#      4           0.000392 -5.109300e-03  0.000481  0.000364    0.000021
#      5          -0.000055 -3.521824e-05 -0.000081 -0.000053   -0.000158
#      6           0.000079  1.842435e-06  0.000047  0.000205    0.000215
#      7          -0.000059  5.938087e-07 -0.000020 -0.000179   -0.000097
#      8           0.000038 -1.288771e-04 -0.000151 -0.000102   -0.000176
#      9          -0.000204 -6.002093e-05 -0.000039 -0.000098   -0.000044
#      10          0.000041 -4.439078e-05 -0.000011  0.000111    0.000122
#      11         -0.000157  1.097648e-03 -0.000078 -0.000204   -0.000201
#      12          0.000157 -2.463186e-03  0.000194  0.000211    0.000139
# 2018 1          -0.000321 -9.236763e-04 -0.000399 -0.000374    0.000026
#      2          -0.000241  2.961532e-04 -0.000175 -0.000213   -0.000579
#      3           0.000229           NaN  0.000065  0.000373    0.000229
#      4           0.000051          -inf -0.000179  0.000252   -0.000030
#      5           0.000255  3.446340e-03  0.000632 -0.000014    0.000244
#      6           0.000182  3.321320e-04  0.000194  0.000122    0.000216
#      7          -0.000118 -3.697364e-05 -0.000123 -0.000141   -0.000113
#      8          -0.000058 -1.420839e-04 -0.000077 -0.000047   -0.000082
#      9           0.000014  2.750365e-05  0.000020  0.000004    0.000017
#      10          0.000142  1.483173e-04  0.000185  0.000241    0.000206
#      11         -0.000474 -4.287031e-03 -0.000506 -0.000609   -0.000241
#      12          0.000264           NaN  0.000256  0.000291   -0.000048
# 2019 1          -0.000062 -1.815853e-04 -0.000068 -0.000055   -0.000030
#      2           0.000017  1.216084e-04  0.000011  0.000015   -0.000035
#      3           0.000284           NaN  0.000404  0.000327    0.000375
#      4          -0.000641           NaN -0.000543 -0.000469   -0.000462
#      5           0.000387  7.573844e-04  0.000209  0.000255    0.000215
#      6          -0.000353 -1.850989e-04 -0.000327 -0.000379   -0.000312
#      7           0.000072 -1.673445e-04  0.000024  0.000097   -0.000002
#      8           0.000075  6.418196e-05  0.000068  0.000090    0.000070
#      9          -0.000035 -1.169280e-03 -0.000149  0.000165   -0.000049
#      10          0.000229          -inf  0.000369  0.000080    0.000266
#      11         -0.000260 -1.018547e-03 -0.000336 -0.000354   -0.000337
#      12         -0.000230  5.241410e-04 -0.000170 -0.000206   -0.000173
#
# SettlementPoint       LZ_LCRA  LZ_NORTH  LZ_RAYBN  LZ_SOUTH   LZ_WEST
# Date Date
# 2016 1          -3.630779e-04 -0.000362 -0.000362 -0.000355 -0.000363
#      2          -7.217515e-04 -0.000744 -0.000737 -0.000874       NaN
#      3           7.175110e-04  0.000738  0.000732  0.000920  0.000861
#      4          -5.065233e-05 -0.000040 -0.000043 -0.000094 -0.000064
#      5           1.591636e-04  0.000130  0.000134  0.000180  0.000158
#      6           4.789818e-04  0.000489  0.000488  0.000450  0.000484
#      7          -1.595192e-04 -0.000132 -0.000125 -0.000154 -0.000169
#      8           9.581242e-05  0.000078  0.000070  0.000100  0.000115
#      9          -8.641162e-05 -0.000083 -0.000085 -0.000088 -0.000086
#      10         -1.662542e-04 -0.000237 -0.000156 -0.000147 -0.000434
#      11          1.556826e-04  0.000223  0.000142  0.000130  0.000431
#      12          3.179422e-04  0.000320  0.000319  0.000312  0.000317
# 2017 1          -4.602379e-04 -0.000450 -0.000452 -0.000472 -0.000341
#      2          -3.461841e-04 -0.000465 -0.000008 -0.000301  0.007667
#      3           3.009024e-04  0.000291  0.000114  0.000356  0.000989
#      4           4.162556e-04  0.000492  0.000250  0.000345  0.001433
#      5          -6.623025e-05 -0.000035 -0.000035  0.000010 -0.000030
#      6           5.371563e-05  0.000029  0.000024  0.000294  0.000025
#      7          -2.136723e-05 -0.000028 -0.000024 -0.000330 -0.000028
#      8          -1.951189e-04 -0.000128 -0.000128  0.000366 -0.000107
#      9          -6.956619e-07 -0.000057 -0.000058 -0.000369 -0.000083
#      10          1.539941e-05 -0.000065 -0.000066 -0.000044 -0.000040
#      11         -1.236662e-04 -0.000007 -0.000007 -0.000166 -0.000009
#      12          2.172382e-04  0.000207  0.000212  0.000139 -0.000345
# 2018 1          -3.827541e-04 -0.000485 -0.000226 -0.000358 -0.000867
#      2          -1.882000e-04 -0.000024 -0.000194 -0.000176  0.000416
#      3           8.954838e-05  0.000017 -0.000027  0.000196 -0.000103
#      4          -1.525690e-04  0.000279  0.000871  0.000192 -0.004700
#      5           6.121983e-04  0.000095 -0.000555  0.000143  0.004655
#      6           1.626640e-04  0.000249  0.000265  0.000132  0.000320
#      7          -1.274450e-04 -0.000091 -0.000092 -0.000140 -0.001793
#      8          -6.633451e-05 -0.000132 -0.000135 -0.000007 -0.000117
#      9           6.565299e-07  0.000010  0.000008  0.000002  0.000041
#      10          1.743067e-04  0.000216  0.000218  0.000159  0.000084
#      11         -5.323565e-04  0.000133  0.000921 -0.000459 -0.002152
#      12          3.009060e-04 -0.000330 -0.001088  0.000251  0.002229
# 2019 1          -6.777212e-05 -0.000069 -0.000013 -0.000089 -0.000429
#      2           1.214159e-05  0.000005 -0.000055  0.000054  0.000334
#      3           3.453632e-04  0.000361  0.000361  0.000427  0.000443
#      4          -5.241335e-04 -0.000347  0.000012 -0.000843 -0.000982
#      5           2.469801e-04  0.000091 -0.000258  0.000432  0.000979
#      6          -3.304388e-04 -0.000270 -0.000267 -0.000181  0.000106
#      7           2.895809e-05 -0.000046 -0.000051 -0.000136 -0.000847
#      8           6.750942e-05  0.000067  0.000067  0.000074 -0.000010
#      9          -1.624150e-04 -0.000270 -0.000133  0.000035 -0.000488
#      10          3.907042e-04  0.000500  0.000364  0.000162  0.001935
#      11         -3.409957e-04 -0.000403 -0.000253 -0.000180  0.000226
#      12         -1.733353e-04 -0.000126 -0.000267 -0.000310 -0.001834

# %%
Prices_log_returns_month = pd.melt(Prices_log_returns_month, value_vars=Prices_log_returns_month.columns, ignore_index=False)

# %%
Prices_log_returns_month.index.rename(['year', 'month'], inplace=True)

# %%
Prices_log_returns_month.reset_index(inplace=True)

# %%
Prices_log_returns_month.set_index(['SettlementPoint', 'year', 'month'], inplace=True)

# %%
Prices_log_returns_month
# Out:
#                                value
# SettlementPoint year month
# HB_BUSAVG       2016 1     -0.000364
#                      2     -0.000782
#                      3      0.000774
#                      4     -0.000049
#                      5      0.000150
# ...                              ...
# LZ_WEST         2019 8     -0.000010
#                      9     -0.000488
#                      10     0.001935
#                      11     0.000226
#                      12    -0.001834
#
# [720 rows x 1 columns]

# %% [markdown]
# ## Task 4: Write the results to file

# %%
# merge results
powerPrices_stats = powerPrices_stats.join(Prices_log_returns_month)

# %%
powerPrices_stats.columns = ['Mean', 'Min', 'Max', 'SD', 'Volatility']

# %%
# write to csv
powerPrices_stats.to_csv('MonthlyPowerPriceStatistics.csv')

# %% [markdown]
# ## Task 5: Expand the contracts across relevant time periods
